# %% [markdown]
# <a href="https://colab.research.google.com/github/MeyrickCharlieEcon/MeyrickCharlieEcon/blob/main/CricketScraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# New project: the aim of this scraper is to pull data from the Cricinfo website and report back "who is batting". By taking a note of the time, and running the report over a set time period. We can count how long each player is on strike at the crease.

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

# %%
URL = "https://www.espncricinfo.com/series/india-tour-of-england-2021-1239527/england-vs-india-1st-test-1239543/live-cricket-score"
html = requests.get(URL)
soup = BeautifulSoup(html.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><link crossorigin="anonymous" href="https://wassets.hscicdn.com" rel="preconnect"/><link crossorigin="anonymous" href="https://img1.hscicdn.com" rel="preconnect"/><script type="text/javascript">
#           /*! js-cookie v3.0.0-rc.0 | MIT */
# ...

# %%
bat = soup.find_all("a", class_= "player-name")
name = bat[0].text
date = pd.to_datetime('today').normalize()
results = [name, date]

# %%
bat
# Out:
# [<a class="player-name" data-hover="" href="/player/jasprit-bumrah-625383" rel="" target="_self">Jasprit Bumrah<span>*</span> <span class="player-style">(<!-- -->Rhb<!-- -->)</span></a>,
#  <a class="player-name" data-hover="" href="/player/mohammed-shami-481896" rel="" target="_self">Mohammed Shami<span></span> <span class="player-style">(<!-- -->Rhb<!-- -->)</span></a>,
#  <a class="player-name" data-hover="" href="/player/sam-curran-662973" rel="" target="_self">Sam Curran<!-- --> <span class="player-style">(<!-- -->Lmf<!-- -->)</span></a>,
#  <a class="player-name" data-hover="" href="/player/ollie-robinson-527776" rel="" target="_self">Ollie Robinson<!-- --> <span class="player-style">(<!-- -->Rmf<!-- -->)</span></a>]

# %%
bat[0].text
# Out:
# 'Jasprit Bumrah*\xa0(Rhb)'

# %%
results
# Out:
# ['Jasprit Bumrah*\xa0(Rhb)', Timestamp('2021-08-06 00:00:00')]
